# %%
import pandas as pd
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This example uses Python 2.7 and the python-request library.

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2024-11-26T10:24:09.442Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 4043, 'name': 'ljqc2tdw3fr', 'symbol': 'qhf83ij8gjh', 'slug': 'mddfdrdno4', 'cmc_rank': 9012, 'num_market_pairs': 6449, 'circulating_supply': 9258, 'total_supply': 8779, 'max_supply': 2889, 'infinite_supply': None, 'last_updated': '2024-11-26T10:24:09.442Z', 'date_added': '2024-11-26T10:24:09.442Z', 'tags': ['et7vyzhtlwm', 'n97ao17620a', '1uzbnqg8u51', 'syeq750w2z', 'm9baz6ojcwb', '15smrjq5pxc', 'uu6sus4znlj', 'cavl2il38lc', '5pk0e8jnq29', 'ljjpmbrpwla'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7533673576394802, 'volume_24h': 371, 'volume_change_24h': 0.9669726184429586, 'percent_change_1h': 0.7809584406710848, 'percent_change_24h': 0.4681810474681818, 'percent_change_7d': 0.4055248312187367, 'market_cap': 0.4821583532693545, 'market_cap_dominance': 3981, 'fully_diluted_market_cap': 0.24830676666379659, 'last_updated': '2024-11-26T10:24:09.442Z'}}}, {'id': 2143, 'name': 'toej0p4ozr', 'symbol': 'nmek4141x08', 'slug': 'jk8esqiu5ds', 'cmc_rank': 3335, 'num_market_pairs': 1457, 'circulating_supply': 1529, 'total_supply': 8467, 'max_supply': 1056, 'infinite_supply': None, 'last_updated': '2024-11-26T10:24:09.442Z', 'date_added': '2024-11-26T10:24:09.442Z', 'tags': ['8rs9e1ki0ko', 'cer9xpfoo7f', 'y7h3zylrsng', 'nc8670qmf2o', 'sinkm21l0a', '47ollxxbls6', '28beyypsofu', 'rhtvtr9owt', '4hyl3vwms5n', '3yuykm9rl3m'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5448804538380814, 'volume_24h': 601, 'volume_change_24h': 0.9071836975089336, 'percent_change_1h': 0.21254227366740852, 'percent_change_24h': 0.4330075609284536, 'percent_change_7d': 0.18088155565569086, 'market_cap': 0.5668524287371526, 'market_cap_dominance': 3840, 'fully_diluted_market_cap': 0.07286892921662802, 'last_updated': '2024-11-26T10:24:09.442Z'}}}, {'id': 6529, 'name': 'icdbqt568op', 'symbol': 'vt1vb6rmy3q', 'slug': 'paskwcqf2si', 'cmc_rank': 47, 'num_market_pairs': 7754, 'circulating_supply': 8079, 'total_supply': 1601, 'max_supply': 5522, 'infinite_supply': None, 'last_updated': '2024-11-26T10:24:09.442Z', 'date_added': '2024-11-26T10:24:09.442Z', 'tags': ['tj9ybc3lgg', 'vznd5805wai', '952q3uw6p4', '2yr3dx25v8r', 'lahtcymsjl', 'bo3jms3bneh', '6riur9kc8jg', '7nycu3rf1un', 'w7vbe4p9xz', 'hl0u8syzc8s'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5428011505351737, 'volume_24h': 9055, 'volume_change_24h': 0.7217647833243817, 'percent_change_1h': 0.08318153505807913, 'percent_change_24h': 0.04187079109883518, 'percent_change_7d': 0.5239837885904639, 'market_cap': 0.7159420530596945, 'market_cap_dominance': 7272, 'fully_diluted_market_cap': 0.9547730651707556, 'last_updated': '2024-11-26T10:24:09.442Z'}}}, {'id': 7728, 'name': 'mm2kt8w2nge', 'symbol': 'k7fcws4enij', 'slug': '8lst7xqmgp', 'cmc_rank': 5527, 'num_market_pairs': 9374, 'circulating_supply': 9293, 'total_supply': 1852, 'max_supply': 7059, 'infinite_supply': None, 'last_updated': '2024-11-26T10:24:09.442Z', 'date_added': '2024-11-26T10:24:09.442Z', 'tags': ['lfc9w6a4vie', 'srrf6ea7w1n', 'wth9r0uirw', 'bjjc3giy02k', 'p325u2z0i', '2pb2ml13dp', '8tb9clo1x8u', 'ez4di71qwxu', 'ayo9ixiqtf', '4y61fptjdpx'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5884233677763477, 'volume_24h': 9446, 'volume_change_24h': 0.6783380260892458, 'percent_change_1h': 0.7618702200648371, 'percent_change_24h': 0.37892544999902933, 'percent_change_7d': 0.8702397927426571, 'market_cap': 0.6160464447387812, 'market_cap_dominance': 1112, 'fully_diluted_market_cap': 0.4621944388304935, 'last_updated': '2024-11-26T10:24:09.442Z'}}}, {'id': 547, 'name': '63abgpy7d4', 'symbol':  ...

# %%
api_key ='fc8fe976-b35f-4c8e-8fed-def5b2c20729'

url = 'https://pro-api.coinmarketcap.com'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fc8fe976-b35f-4c8e-8fed-def5b2c20729',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'statusCode': 404, 'error': 'Not Found', 'message': 'Not Found'}

# %% [markdown]
# # PART 1

# %%
import pandas as pd
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'2700',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fc8fe976-b35f-4c8e-8fed-def5b2c20729',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
# Out:
# {'status': {'timestamp': '2024-11-26T10:45:57.663Z', 'error_code': 0, 'error_message': None, 'elapsed': 342, 'credit_count': 14, 'notice': None, 'total_count': 10193}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11808, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19787634, 'total_supply': 19787634, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-11-26T10:45:00.000Z', 'quote': {'USD': {'price': 92640.00723854727, 'volume_24h': 89057293474.23473, 'volume_change_24h': 52.7441, 'percent_change_1h': -0.8354135, 'percent_change_24h': -5.79017079, 'percent_change_7d': 0.98079703, 'percent_change_30d': 38.25867069, 'percent_change_60d': 41.25275237, 'percent_change_90d': 54.90134834, 'market_cap': 1833126556993.724, 'market_cap_dominance': 57.6645, 'fully_diluted_market_cap': 1945440152009.49, 'tvl': None, 'last_updated': '2024-11-26T10:45:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9592, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120433832.8640161, 'total_supply': 120433832.8640161, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-11-26T10:45:00.000Z', 'quote': {'USD': {'price': 3332.4731680483383, 'volume_24h': 52324437294.362564, 'volume_change_24h': 59.6965, 'percent_change_1h': -0.95599526, 'percent_change_24h': -5.24849668, 'percent_change_7d': 6.87740085, 'percent_change_30d': 35.20221274, 'percent_change_60d': 25.96037678, 'percent_change_90d': 32.17948831, 'market_cap': 401342516544.5518, 'market_cap_dominance': 12.6131, 'fully_diluted_market_cap': 401342516544.55, 'tvl': None, 'last_updated': '2024-11-26T10:45:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 105274, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 132744005559.75017, 'total_supply': 135944368167.2145, 'platform': {'id ...

# %%
#This normalizes the data and makes it all pretty in a dataframe
df = pd.json_normalize(data['data'])

# %%
df.tail(3)
# Out:
#          id            name symbol       slug  num_market_pairs  \
# 2697  10905         AirNFTs   AIRT    airnfts                17
# 2698  19460  Spume Protocol  SPUME      spume                 7
# 2699   8970            Lokr    LKR  polkalokr                 8
#
#                     date_added  \
# 2697  2021-07-15T00:00:00.000Z
# 2698  2022-04-11T07:49:46.000Z
# 2699  2021-04-07T00:00:00.000Z
#
#                                                    tags    max_supply  \
# 2697  [collectibles-nfts, gaming, launchpad, bnb-chain]  1.000000e+09
# 2698                                                 []           NaN
# 2699                                                 []  1.000000e+08
#
#       circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 2697        1.120400e+08   886000000.0            False       NaN      2698
# 2698        4.934460e+07   100000000.0            False       NaN      2699
# 2699        2.562827e+07   100000000.0            False       NaN      2700
#
#       self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 2697                       112040000.0              21571.758847        NaN
# 2698                        15000000.0               6444.481506        NaN
# 2699                        37946291.0              30628.917413        NaN
#
#                   last_updated  quote.USD.price  quote.USD.volume_24h  \
# 2697  2024-11-26T10:45:00.000Z         0.000193           1980.825767
# 2698  2024-11-26T10:45:00.000Z         0.000430            101.606178
# 2699  2024-11-26T10:45:00.000Z         0.000807         272381.938619
#
#       quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 2697                     460.0903                    -0.108730
# 2698                     -63.8561                    -0.051735
# 2699                       2.5057                    -2.303679
#
#       quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 2697                     -9.885039                    -6.237123
# 2698                    -12.029876                    13.700404
# 2699                      0.560124                     0.309258
#
#       quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 2697                    -21.222331                    -25.783142
# 2698                     10.865410                    -21.801270
# 2699                    -14.287602                    -17.763719
#
#       quote.USD.percent_change_90d  quote.USD.market_cap  \
# 2697                    -20.108321          21571.758847
# 2698                      8.494473          21200.023991
# 2699                    -15.841566          20686.244653
#
#       quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 2697                             0.0                           192536.23
# 2698                             0.0                            42963.21
# 2699                             0.0                            80716.50
#
#       quote.USD.tvl    quote.USD.last_updated  platform.id  \
# 2697            NaN  2024-11-26T10:45:00.000Z       1839.0
# 2698            NaN  2024-11-26T10:45:00.000Z       1027.0
# 2699            NaN  2024-11-26T10:45:00.000Z       1027.0
#
#                 platform.name platform.symbol platform.slug  \
# 2697  BNB Smart Chain (BEP20)             BNB           bnb
# 2698                 Ethereum             ETH      ethereum
# 2699                 Ethereum             ETH      ethereum
#
#                           platform.token_address
# 2697  0x016cf83732f1468150d87dcc5bdf67730b3934d3
# 2698  0xa16a609fF4e1A15b6cCb469E7a5dD14E89305283
# 2699  0x80ce3027a70e0a928d9268994e9b85d03bd4cdcf

# %%
# data_json = json.dumps(data, indent=4)
# print(data_json)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # PART  2

# %% [markdown]
# ...
